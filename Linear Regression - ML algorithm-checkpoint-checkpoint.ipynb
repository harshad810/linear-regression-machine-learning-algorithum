# %% [raw]
# # A linear regression is a machine learning algorithm based on supervised learning
# It performs a regression task on the basis of two variables (independent & dependent)
# It is mostly used for forecasting and finding out relationship between two variables
# y = b0+b1x1+e
# y -> dependent variable
# x -> independent variable
# b -> coefficient
# e -> error value

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Housing_Data.csv')

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
# x is independent variable
x= df[[
    'Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms',
 'Area Population'
      ]]

# %%
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
#y is dependent variable
y=df['Price']

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2939      87541.452878             6.570194                   6.399107
# 3757      45862.131380             5.453673                   5.128001
# 3689      67706.819488             7.499371                   7.878963
# 2407      75302.111424             6.295261                   8.482699
# 1661      48735.924512             5.543730                   6.091906
# ...                ...                  ...                        ...
# 270       61957.154304             7.841081                   7.472967
# 3236      59940.065131             6.265751                   6.888069
# 1509      82321.731112             5.911488                   6.813650
# 1313      60960.463540             3.696844                   7.768934
# 4873      63162.176403             4.267963                   8.824856
#
#       Avg. Area Number of Bedrooms  Area Population
# 2939                          3.22     31044.979467
# ...

# %%
x_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2615      90863.999992             6.313891                   6.370261
# 2139      56986.833131             5.733519                   7.883281
# 3741      58308.668265             7.097220                   6.701060
# 2693      72363.204175             4.509671                   4.525421
# 2891      50521.463558             7.374458                   7.149612
# ...                ...                  ...                        ...
# 1619      60610.610637             4.019357                   5.539636
# 3856      69518.481724             6.728848                   7.415806
# 678       65124.656023             4.886834                   6.370539
# 3477      59314.788476             4.950181                   5.857573
# 4767      76187.273309             6.156222                   7.166149
#
#       Avg. Area Number of Bedrooms  Area Population
# 2615                          2.44     41837.475171
# ...

# %%
y_train
# Out:
# 2939    1.603046e+06
# 3757    5.763560e+05
# 3689    1.761924e+06
# 2407    1.643339e+06
# 1661    1.515271e+05
#             ...
# 270     1.338044e+06
# 3236    1.063743e+06
# 1509    1.574085e+06
# 1313    5.840612e+05
# 4873    1.203094e+06
# Name: Price, Length: 3500, dtype: float64

# %%
y_test
# Out:
# 2615    1.746087e+06
# 2139    1.239310e+06
# 3741    1.364832e+06
# 2693    7.921742e+05
# 2891    1.204117e+06
#             ...
# 1619    6.891556e+05
# 3856    1.527492e+06
# 678     6.224496e+05
# 3477    4.700081e+05
# 4767    1.618721e+06
# Name: Price, Length: 1500, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model =LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [2.14551106e+01 1.64689721e+05 1.19253097e+05 1.70387752e+03
#  1.53577203e+01]

# %%
columns_coef=pd.DataFrame(model.coef_,x.columns,columns=['Coef value'])

# %%
columns_coef
# Out:
#                                  Coef value
# Avg. Area Income                  21.455111
# Avg. Area House Age           164689.721302
# Avg. Area Number of Rooms     119253.097088
# Avg. Area Number of Bedrooms    1703.877517
# Area Population                   15.357720

# %% [markdown]
# # PREDICTION

# %%
prediction =model.predict(x_test)

# %%
print(prediction)
# Out:
# [1776219.05783724 1170883.06448028 1188707.43698495 ...  643571.57300886
#   508643.43224344 1581638.50850392]

# %%
plt.figure(figsize=(12,10))
plt.scatter(y_test,prediction)
plt.xlabel('Y TESTING PRICE')
plt.ylabel('PREDICTION PRICE')
# Out:
# Text(0, 0.5, 'PREDICTION PRICE')

# %%
df1= pd.read_csv('House.csv')

# %%
df1
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df1['mainroad'] = df1['mainroad'].replace(['yes','no'],[1,0])

# %%
df1['guestroom'] = df1['guestroom'].replace(['yes','no'],[1,0])

# %%
df1['basement'] = df1['basement'].replace(['yes','no'],[1,0])

# %%
df1['hotwaterheating'] = df1['hotwaterheating'].replace(['yes','no'],[1,0])

# %%
df1['airconditioning'] = df1['airconditioning'].replace(['yes','no'],[1,0])

# %%
df1['prefarea'] = df1['prefarea'].replace(['yes','no'],[1,0])

# %%
df1['furnishingstatus'] = df1['furnishingstatus'].replace(['semi-furnished','furnished','unfurnished'],[1,2,0])

# %%
df1
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
x = df1[[
    'area','bedrooms','bathrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus'
]]

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
y = df1['price']

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 510  2880         3          1        1         0          0         0
# 411  2145         3          1        3         1          0         0
# 490  4350         3          1        2         0          0         0
# 19   6420         3          2        2         1          0         0
# 312  3600         3          1        1         1          0         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 323  5400         3          1        1         1          0         0
# 420  4120         2          1        2         1          0         0
# 173  5300         4          2        1         1          0         0
# 518  3500         2          1        1         1          1         0
# 32   4880         4          2        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
x_test
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 76   6420         3          2        3         1          0         0
# 318  4340         3          1        1         1          0         0
# 91   6750         2          1        1         1          1         1
# 354  8400         2          1        1         1          0         0
# 329  3960         3          1        2         1          0         0
# ..    ...       ...        ...      ...       ...        ...       ...
# 88   7410         3          1        1         1          1         1
# 316  5900         4          2        2         0          0         1
# 407  2145         3          1        3         1          0         0
# 388  3650         3          1        2         1          0         0
# 100  6600         3          2        1         1          0         1
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
y_test
# Out:
# 76     6650000
# 318    4060000
# 91     6419000
# 354    3780000
# 329    3990000
#         ...
# 88     6475000
# 316    4060000
# 407    3465000
# 388    3500000
# 100    6230000
# Name: price, Length: 164, dtype: int64

# %%
y_train
# Out:
# 510    2520000
# 411    3430000
# 490    2835000
# 19     8855000
# 312    4098500
#         ...
# 323    4025000
# 420    3360000
# 173    5250000
# 518    2450000
# 32     8295000
# Name: price, Length: 381, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [2.27110923e+02 1.80081883e+05 9.79992805e+05 4.51907711e+05
#  3.64085052e+05 2.96709699e+05 2.82945177e+05 8.03073571e+05
#  8.44052786e+05 2.00456510e+05 6.65580014e+05 2.36794442e+05]

# %%
pd.DataFrame(model.coef_,x.columns,columns=['Coeff Value'])
# Out:
#                     Coeff Value
# area                 227.110923
# bedrooms          180081.883457
# bathrooms         979992.804675
# stories           451907.711385
# mainroad          364085.052434
# guestroom         296709.698582
# basement          282945.176755
# hotwaterheating   803073.570770
# airconditioning   844052.786055
# parking           200456.510140
# prefarea          665580.013866
# furnishingstatus  236794.442049

# %% [markdown]
# # Prediction

# %%
prediction = model.predict(x_test)

# %%
print(prediction)
# Out:
# [7370555.12717071 3267928.9386457  5518126.73030522 4447168.35333236
#  3870328.94147315 7640643.80065659 5040247.35337875 7041253.27879098
#  4519087.30803073 4394708.72982697 2883469.37218802 3635184.37877213
#  3576392.78901098 4883473.7298397  6439950.65920225 2587603.9428662
#  4960649.2210942  4236513.99905675 2919850.14449845 6625826.47532766
#  3019006.20219794 5278019.70736337 4246448.28482704 5737270.82362395
#  3939657.84134131 5029100.10178529 5263228.95508489 3051422.96124702
#  3367459.52961181 5537496.3308008  3320763.16477892 4164554.08004618
#  5202226.1993833  3143594.96297698 2692074.9672847  4709079.87609665
#  4495525.71736824 2438021.42919651 4482333.04615885 6361187.40266988
#  2815934.00448431 2768176.41511687 3761917.34279093 4218059.60378114
#  5499080.11270574 6015466.67683694 3606281.00442077 3042447.01804226
#  4038665.50241979 7484719.53037797 4033848.62149515 3911396.57417096
#  8030186.5640795  2681383.67571708 2682990.53037874 4929083.79970519
# ...

# %%
plt.figure(figsize=(12,10))
plt.scatter(y_test,prediction)

plt.xlabel('Y TESTING PRICE')
plt.ylabel('PREDICTION PRICE')
# Out:
# Text(0, 0.5, 'PREDICTION PRICE')
